# %% [markdown]
# ## conda 基本操作
#
# ### 环境相关操作
# #### 创建环境
# 这个还是建议在 $Anaconda Navigator$ 中操作
#
# #### 激活环境
# 这个使用场景是在某指定环境中安装某版本的$pytorch$(注意是在Anaconda Prompt)中操作
# ```
# conda activate my_env
# ```
#
# #### 删除环境
# ```
# conda env remove --name myenv
# ```
#
# #### 查看环境下有哪些包
# ```
# conda list
# ```
#
# #### 删除环境下的某个包
# ```
# conda remove package_name
# ```
